# %%
from magali.stereogram_projection import Stereoplot
import matplotlib.pyplot as plt
import numpy as np

# %%
# Example data: simulated magnetic field orientations
azimuths = np.random.uniform(0, 360, 100)  # Random azimuth angles in degrees
inclinations = np.random.uniform(-90, 90, 100)  # Random inclination angles in degrees


# Project the data
x, y = Stereoplot.calculate_stereonet_projection(azimuths, inclinations)

# Create a plot using the Stereoplot projection
fig, ax = plt.subplots(subplot_kw={"projection": "stereoplot"})
ax.scatter(x, y, color='b', s=10, alpha=0.7, label="Magnetic Vectors")
ax.set_title("Stereogram of Magnetic Field Orientations")
ax.legend()

# Display the plot
plt.show()
